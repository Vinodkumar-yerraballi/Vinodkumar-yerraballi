# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/vinod/Downloads/Python-3.10.3/weatherHistory.csv')
df.head(5)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df.isnull().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.dropna(how='any',inplace=True)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df['Precip Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (95936, 12)

# %%
df[df.duplicated()]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 36072  2010-08-02 00:00:00.000 +0200          Clear        rain
# 36073  2010-08-02 01:00:00.000 +0200          Clear        rain
# 36074  2010-08-02 02:00:00.000 +0200          Clear        rain
# 36075  2010-08-02 03:00:00.000 +0200          Clear        rain
# 36076  2010-08-02 04:00:00.000 +0200          Clear        rain
# 36077  2010-08-02 05:00:00.000 +0200          Clear        rain
# 36078  2010-08-02 06:00:00.000 +0200          Clear        rain
# 36079  2010-08-02 07:00:00.000 +0200          Clear        rain
# 36080  2010-08-02 08:00:00.000 +0200          Clear        rain
# 36081  2010-08-02 09:00:00.000 +0200          Clear        rain
# 36082  2010-08-02 10:00:00.000 +0200          Clear        rain
# 36083  2010-08-02 11:00:00.000 +0200          Clear        rain
# 36084  2010-08-02 12:00:00.000 +0200          Clear        rain
# 36085  2010-08-02 13:00:00.000 +0200  Partly Cloudy        rain
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (95912, 12)

# %%
df.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
sns.scatterplot(x='Temperature (C)',y='Humidity',data=df)
# Out:
# <AxesSubplot:xlabel='Temperature (C)', ylabel='Humidity'>

# %%
sns.set_style("ticks")
sns.pairplot(df)
plt.show()

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
sns.boxplot(x='Temperature (C)',data=df)
# Out:
# <AxesSubplot:xlabel='Temperature (C)'>

# %%
df.loc[:,['Temperature (C)','Apparent Temperature (C)']].head(5)
# Out:
#    Temperature (C)  Apparent Temperature (C)
# 0         9.472222                  7.388889
# 1         9.355556                  7.227778
# 2         9.377778                  9.377778
# 3         8.288889                  5.944444
# 4         8.755556                  6.977778

# %%
x=df['Temperature (C)'].values
y=df['Apparent Temperature (C)'].values

# %%
x
# Out:
# array([ 9.47222222,  9.35555556,  9.37777778, ..., 22.03888889,
#        21.52222222, 20.43888889])

# %%
y
# Out:
# array([ 7.38888889,  7.22777778,  9.37777778, ..., 22.03888889,
#        21.52222222, 20.43888889])

# %%
sns.scatterplot(x='Temperature (C)',y='Apparent Temperature (C)',data=df)
plt.title("THe relation  of temparature and apparent temparature")
plt.xlabel("temparature")
plt.ylabel("Apperent temparature")
# Out:
# Text(0, 0.5, 'Apperent temparature')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=42)

# %%
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

# %%
x_train.shape
# Out:
# (76729, 1)

# %%
y_train.shape
# Out:
# (76729, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lm.predict(x_test)

# %%
y_pred
# Out:
# array([[ 8.69512582],
#        [19.54129504],
#        [22.37475644],
#        ...,
#        [ 0.05893302],
#        [11.17671946],
#        [-1.92263803]])

# %%
a=lm.coef_
b=lm.intercept_,

# %%
print("Estimated model slop a:",a)
print("Estimated model intercept b:",b)
# Out:
# Estimated model slop a: [[1.11116133]]
# Estimated model intercept b: (array([-2.40414127]),)

# %%
from sklearn.metrics import accuracy_score

# %%
test_score=lm.score(x_train,y_train)
print("accuracy of the test score",test_score)
# Out:
# accuracy of the test score 0.9853072560654853

# %%
test_score1=lm.score(x_test,y_test)
print("accuracy of the test score",test_score1)
# Out:
# accuracy of the test score 0.9853811631406214

# %%
new_data=np.array([8]).reshape(-1,1)

# %%
new_data
# Out:
# array([[8]])

# %%
lm.predict(new_data)
# Out:
# array([[6.48514939]])

# %%
# %matplotlib inline
plt.scatter(x,y,color="blue")
plt.plot(x_test,y_pred,color="red",linewidth=2)
plt.xlabel("Temparature")
plt.ylabel("Humidity")
plt.title("Apperent temparature")
# Out:
# Text(0.5, 1.0, 'Apperent temparature')

# %%
plt.scatter(x_test,y_test,color="blue")
plt.scatter(x_test,y_pred,color="red")
plt.xlabel("Temparature")
plt.ylabel("Humidity")
plt.title("Apperent temparature")
# Out:
# Text(0.5, 1.0, 'Apperent temparature')

# %%
x.std()
# Out:
# 9.569570100671845

# %%
y.std()
# Out:
# 10.716655509816283

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
rsem=np.sqrt(mse)

# %%
print("RMSE value{:.4f}",format(rsem))
# Out:
# RMSE value{:.4f} 1.2987780425638522

# %%
from sklearn.metrics import r2_score

# %%
print("R2 score value{:.4f}".format(r2_score(y_test,y_pred)))
# Out:
# R2 score value0.9854
